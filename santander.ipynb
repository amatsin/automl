# %%
# %cd ../src
# Out:
# /Users/kristjan.roosild/OneDrive/kool/AutoML/projekt/src

# %%
import extra_tree
# Out:
# Model: extra_tree__folds5
# Reading training data
# Current Fold: 0
# AUC = 0.5279026822365864
# Current Fold: 1
# AUC = 0.5301109680658019
# Current Fold: 2
# AUC = 0.5297000268252955
# Current Fold: 3
# AUC = 0.5285396253861321
# Current Fold: 4
# AUC = 0.5227334699487554
# Overall AUC = 0.5277972854249073
# Saving OOF predictions
# Saving code to reproduce
# Saving submission file

# %%
import lgbm
# Out:
# Model: lgbm__folds5
# Reading training data
# Current Fold: 0
# AUC = 0.5466765901627092
# Current Fold: 1
# AUC = 0.5484322131834267
# Current Fold: 2
# AUC = 0.5460150608823586
# Current Fold: 3
# AUC = 0.5506177423057033
# Current Fold: 4
# AUC = 0.5449366563513727
# Overall AUC = 0.547335632194058
# Saving OOF predictions
# Saving code to reproduce
# Saving submission file

# %%
import xgb
# Out:
# Model: xgb__folds5
# Reading training data
# Current Fold: 0
# /Users/kristjan.roosild/opt/miniconda3/envs/py38/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:49:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# AUC = 0.614547893973983
# Current Fold: 1
# ...

# %%
import cb
# Out:
# Model: cb__folds5
# Reading training data
# Current Fold: 0
# Learning rate set to 0.089969
# 0:	learn: 0.6178986	total: 106ms	remaining: 1m 46s
# 1:	learn: 0.5570254	total: 152ms	remaining: 1m 15s
# 2:	learn: 0.5094640	total: 194ms	remaining: 1m 4s
# 3:	learn: 0.4703497	total: 237ms	remaining: 58.9s
# 4:	learn: 0.4404204	total: 280ms	remaining: 55.7s
# 5:	learn: 0.4139596	total: 324ms	remaining: 53.6s
# 6:	learn: 0.3938342	total: 364ms	remaining: 51.7s
# 7:	learn: 0.3773126	total: 408ms	remaining: 50.5s
# 8:	learn: 0.3640283	total: 450ms	remaining: 49.5s
# 9:	learn: 0.3534466	total: 490ms	remaining: 48.5s
# 10:	learn: 0.3446110	total: 535ms	remaining: 48.1s
# 11:	learn: 0.3371348	total: 580ms	remaining: 47.7s
# 12:	learn: 0.3309038	total: 616ms	remaining: 46.8s
# 13:	learn: 0.3253684	total: 653ms	remaining: 46s
# 14:	learn: 0.3208722	total: 693ms	remaining: 45.5s
# 15:	learn: 0.3169706	total: 731ms	remaining: 44.9s
# 16:	learn: 0.3136221	total: 769ms	remaining: 44.5s
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
#%cd src
import NaiveBayes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a5b44a02f894> in <module>
#       2 warnings.filterwarnings('ignore')
#       3 #%cd src
# ----> 4 import NaiveBayes
#
# ~\automl\src\NaiveBayes.py in <module>
#       4 import numpy as np
#       5 from sklearn.model_selection import StratifiedKFold
# ----> 6 from dataloader import load_data
#       7 NFOLDS = 5
#       8 RANDOM_STATE = 42
#
# ModuleNotFoundError: No module named 'dataloader'

# %%
import AdaBoost
# Out:
# Model: AdaBoost__folds5
# Reading training data
# Current Fold: 0
# AUC = 0.6256869711916777
# Current Fold: 1
# AUC = 0.6285927958661433
# Current Fold: 2
# AUC = 0.6319195434721887
# Current Fold: 3
# AUC = 0.6281248733607083
# Current Fold: 4
# AUC = 0.629165798200626
# Overall AUC = 0.6286980075713737
# Saving OOF predictions
# Saving code to reproduce
# Saving submission file

# %%
import GM
# Out:
# Model: GM__folds5
# Reading training data
# Current Fold: 0
# AUC = 0.5089651966675061
# Current Fold: 1
# AUC = 0.5117924592871776
# Current Fold: 2
# AUC = 0.5178358485504662
# Current Fold: 3
# AUC = 0.5151824587793861
# Current Fold: 4
# AUC = 0.48479571949858513
# Overall AUC = 0.5077145718345506
# Saving OOF predictions
# Saving code to reproduce
# Saving submission file

# %%
import BayesianRidge
# Out:
# Model: BayesianRidge__folds5
# Reading training data
# Current Fold: 0
# AUC = 0.8589395854445567
# Current Fold: 1
# AUC = 0.8559736336797987
# Current Fold: 2
# AUC = 0.8647994740029701
# Current Fold: 3
# AUC = 0.8600816770700485
# Current Fold: 4
# AUC = 0.8581852515172165
# Overall AUC = 0.8595930122497814
# Saving OOF predictions
# Saving code to reproduce
# Saving submission file
